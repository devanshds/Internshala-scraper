# %%
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup as bs

# %%
key="python"
page=1
l=[]

while page != 0 :

    url="https://internshala.com/internships/keywords-"+key+"/page-"+ str(page)
    r=requests.get(url)
    c=r.content
    soup=bs(c,"html.parser")
    all=soup.find_all("div",{"class":"container-fluid individual_internship"})
    
    #test if isLastPage=1
    test=soup.find("input",{"id":"isLastPage"})
    if test["value"] == "1":
        page=0
    else:
        page+=1

    
    """
    Title, By, Location, Stipend, Duration, Skills, URL
    """
    for item in all:
        d={}
        #Title
        title=item.find("h4")
        try:
            d["Title"]=title["title"]
        except:
            pass
        #By
        by=item.find("a",{"class":"link_display_like_text"})
        try:
            d["By"]=by.text.strip()

        except:
            pass

        #URL
        link=item.find_all("a")
        try:
            d["URL"]="https://www.internshala.com"+[a["href"] for a in link if a["href"].startswith("/internship/detail/")][0]
        except:
            pass

        #Location
        location=item.find("a",{"class":"location_link"})
        try:
            d["Location"]=location.text
        except:
            pass

        #Stipend
        stipend=item.find("i",{"class":"fa fa-inr"})
        try:
            d["Stipend"]="INR " + stipend.next_sibling.strip()
        except:
            pass

        #Duration
        duration=item.find_all("td")
        try:
            d["Duration"]=duration[1].text.strip()
        except:
            pass

        #Skills
        try:
            r1=requests.get(d["URL"])
            c1=r1.content
            soup1=bs(c1,"html.parser")
            skills=soup1.find("span",{"id":"skillNames"})
            d["Skills"]=skills.get_text()
        except:
            pass
        l.append(d)
    print(page)
# Out:
# 2
# 3
# 0

# %%
df=pd.DataFrame(l)
df
# Out:
#                                           Title  \
# 0                         Dashboard Development
# 1                            Python Development
# 2   Content Writing (Java & Python Programming)
# 3            Machine Learning (Computer Vision)
# 4                            Python Development
# ..                                          ...
# 71                    Python/Django Development
# 72                              Web Development
# 73                    Python/Django Development
# 74                           Python Development
# 75                           Python Development
#
#                                      By  \
# 0                           Blackcoffer
# 1                            FreightBro
# 2         Perfectice Eduventure Limited
# 3   Modaka Technologies Private Limited
# 4                                ZIGRAM
# ..                                  ...
# 71         Mudraksh And McShaw Advisory
# 72                           RAPS iTECH
# 73        Credicxo Tech Private Limited
# 74         Aester India Private Limited
# 75                  Rewoke Technologies
#
#                                                   URL        Location  \
# 0   https://www.internshala.com/internship/detail/...  Work From Home
# 1   https://www.internshala.com/internship/detail/...         Chennai
# 2   https://www.internshala.com/internship/detail/...  Work From Home
# 3   https://www.internshala.com/internship/detail/...       Bangalore
# 4   https://www.internshala.com/internship/detail/...         Gurgaon
# ..                                                ...             ...
# 71  https://www.internshala.com/internship/detail/...           Noida
# 72  https://www.internshala.com/internship/detail/...      Chandigarh
# 73  https://www.internshala.com/internship/detail/...           Delhi
# 74  https://www.internshala.com/internship/detail/...           Kochi
# 75                                                NaN     Bhubaneswar
#
#                   Stipend  Duration  \
# 0   INR 6000-10000 /Month  6 Months
# 1        INR 15000 /Month  3 Months
# 2         INR 7000 /Month  2 Months
# 3    INR 3000-5000 /Month  4 Months
# 4        INR 10000 /Month  6 Months
# ..                    ...       ...
# 71        INR 6000 /Month  3 Months
# 72        INR 2500 /Month  6 Months
# 73       INR 15000 /Month  3 Months
# 74        INR 2000 /Month  2 Months
# 75  INR 5000-10000 /Month  2 Months
#
#                                                Skills
# 0   HTML (Learn HTML), CSS (Learn CSS), JavaScript...
# 1             MySQL, Python (Learn Python) and Django
# 2         Java (Learn Java) and Python (Learn Python)
# 3   JavaScript, OpenCV, Python (Learn Python) and ...
# 4   Cloud Computing, Python (Learn Python), SQL, D...
# ..                                                ...
# 71                                                SQL
# 72  HTML (Learn HTML), CSS (Learn CSS) and JavaScript
# 73  Python (Learn Python), SQL, MongoDB, Django, J...
# 74  Java (Learn Java), PHP (Learn PHP), Python (Le...
# 75                                                NaN
#
# [76 rows x 7 columns]

# %%
df.to_csv('python.csv')
